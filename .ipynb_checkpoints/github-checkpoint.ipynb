# %% [markdown]
# # Explorando mi Github
# ## Los hábitos de programación

# %%
import json
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import pandas as pd
from datetime import datetime
import os
plt.style.use('ggplot')
# %matplotlib inline

matplotlib.rcParams['font.family'] = 'Open Sans'
def set_title(fig, ax, title, subtitle, rect=[0, 0, 1, 0.9]):
    fig.tight_layout(rect=rect)
    ax.text(0, 1.06, title, va='bottom', transform=ax.transAxes, fontsize=20, fontweight='semibold')
    ax.text(0, 1.05, subtitle, fontsize=17, va='top', transform=ax.transAxes, fontweight='light')

# %% [markdown]
# Lo primero a notar, es que la información se bajó como JSON por cada repositorio, por lo tanto, hay que generar un gran dataset con toda la información comprimida (de ser posible)

# %%
# !ls data/
# Out:
# ADSW                  dotfiles              pong-python
# AID                   feelTheDesktop        projecteuler
# ChatRedes             find-roots            ramos
# ElepemonGO            findfood              redes
# PocketmonGO           genetic_algorithm     semaphore
# SansanoBot            got                   topshows
# StemReveal.js         js_presentations      traductor
# apuntes-mat023        markov-word-generator vimwiki
# blog                  my-facebook-analysis  word-generator
# cv                    personalapps

# %% [markdown]
# Cada json del repositorio contiene solamente los commits, por lo tanto se creará un dataset que los contendrá todos juntos

# %%
files = os.listdir('data/')
files
# Out:
# ['ADSW',
#  'AID',
#  'apuntes-mat023',
#  'blog',
#  'ChatRedes',
#  'cv',
#  'dotfiles',
#  'ElepemonGO',
#  'feelTheDesktop',
#  'find-roots',
#  'findfood',
#  'genetic_algorithm',
#  'got',
#  'js_presentations',
#  'markov-word-generator',
#  'my-facebook-analysis',
#  'personalapps',
#  'PocketmonGO',
#  'pong-python',
#  'projecteuler',
#  'ramos',
#  'redes',
#  'SansanoBot',
#  'semaphore',
#  'StemReveal.js',
#  'topshows',
#  'traductor',
#  'vimwiki',
#  'word-generator']

# %%
with open('data/' + files[0]) as f:
    text = f.read()
json.loads(text)[0].keys()
# Out:
# dict_keys(['sha', 'commit', 'url', 'html_url', 'comments_url', 'author', 'committer', 'parents'])

# %% [markdown]
# Las variables que nos podrían interesar son `author` y `commit`, para identificar los commits propios y la información en sí del commit.

# %%
print(json.loads(text)[0]['author'])
print(json.loads(text)[0]['commit'])
# Out:
# {'login': 'GasparCorrea', 'id': 13988262, 'avatar_url': 'https://avatars1.githubusercontent.com/u/13988262?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/GasparCorrea', 'html_url': 'https://github.com/GasparCorrea', 'followers_url': 'https://api.github.com/users/GasparCorrea/followers', 'following_url': 'https://api.github.com/users/GasparCorrea/following{/other_user}', 'gists_url': 'https://api.github.com/users/GasparCorrea/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/GasparCorrea/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/GasparCorrea/subscriptions', 'organizations_url': 'https://api.github.com/users/GasparCorrea/orgs', 'repos_url': 'https://api.github.com/users/GasparCorrea/repos', 'events_url': 'https://api.github.com/users/GasparCorrea/events{/privacy}', 'received_events_url': 'https://api.github.com/users/GasparCorrea/received_events', 'type': 'User', 'site_admin': False}
# {'author': {'name': 'Gaspar Octavio', 'email': 'gasparcorreavergara@gmail.com', 'date': '2017-09-20T22:49:22Z'}, 'committer': {'name': 'Gaspar Octavio', 'email': 'gasparcorreavergara@gmail.com', 'date': '2017-09-20T22:49:22Z'}, 'message': 'Un pequeño intento de comentar el código', 'tree': {'sha': '9c24a30b0893abad13b19568f8e16c0f1ce3383d', 'url': 'https://api.github.com/repos/GasparCorrea/ADSW/git/trees/9c24a30b0893abad13b19568f8e16c0f1ce3383d'}, 'url': 'https://api.github.com/repos/GasparCorrea/ADSW/git/commits/8dd347487bd1baeb186806f77dd0126e59572e1e', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}

# %% [markdown]
# Finalmente, con la ayuda de `author` se verificará si fui yo quien hizo commit, y con `commit` se sacará la fecha y el mensaje.

# %%
df_dict = {'repository':[], 'message':[], 'time':[]}
for f in files:
    repository = f
    with open("data/" + f) as f:
        text = f.read()
    for commit in json.loads(text):
        if not commit:
            continue
        
        if not 'author' in commit:
            continue
           
        email = commit['commit']['author']['email']
        if "sebastian.aedo" in email or "saedo" in email:
            df_dict['repository'].append(repository)
            df_dict['message'].append(commit['commit']['message'])
            df_dict['time'].append(commit['commit']['author']['date'])

# %%
df = pd.DataFrame(df_dict)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 3 columns):
# message       258 non-null object
# repository    258 non-null object
# time          258 non-null object
# dtypes: object(3)
# memory usage: 6.1+ KB
#                                                message      repository  \
# 0                                       cambiado a SVC             AID
# 1    Merge branch 'master' of https://github.com/et...             AID
# 2    fixeado water, terminando clustering, falta ex...             AID
# 3                                       avanzado tarea             AID
# 4                                  avanzado clustering             AID
# 5                            avanzando en la hepatitis             AID
# 6                           Trabajando en la hepatitis             AID
# 7                                           version py             AID
# 8                                         updateada NN             AID
# 9                                      ported to keras             AID
# 10                                   agregado proyecto             AID
# 11                                   proyecto agregado             AID
# 12                     empezando separación por target             AID
# 13                             added stacked histogram             AID
# 14         añadido boxplot en relacion G3 y studytime.             AID
# 15   falta la descripción y un tercer gráfico para ...             AID
# 16                                         commit test             AID
# 17                                        fixed readme             AID
# 18                                        first commit             AID
# 19                                   siguiendo clase 2  apuntes-mat023
# 20                                         fixed merge  apuntes-mat023
# 21                              avanzada segunda clase  apuntes-mat023
# 22        finalizada primera clase, comenzando segunda  apuntes-mat023
# 23   Merge branch 'master' of https://github.com/et...  apuntes-mat023
# 24                                                test  apuntes-mat023
# 25                                     avanzado cap 00  apuntes-mat023
# 26                                avanzado capitulo 00  apuntes-mat023
# 27                                        First commit  apuntes-mat023
# 28                                     modified images            blog
# 29                                            new note            blog
# ..                                                 ...             ...
# 228  Merge branch 'master' of https://github.com/et...        topshows
# 229                                    added gitignore        topshows
# 230                                   Update README.md        topshows
# 231                                   Update README.md        topshows
# 232                     now show the plots and save it        topshows
# 233  Merge branch 'master' of https://github.com/et...        topshows
# 234          fixed normal distribution -> distribution        topshows
# 235                                   Update README.md        topshows
# 236                                       finally done        topshows
# 237  Merge branch 'master' of https://github.com/et...        topshows
# 238                                       first commit        topshows
# 239                                     Initial commit        topshows
# 240                              fixed folders problem       traductor
# 241                                 reorganizing files       traductor
# 242  Se agregó un diccionario\n\nde ahora en adelan...       traductor
# 243                                      final counter       traductor
# 244                                               test       traductor
# 245                             testeado y funcionando       traductor
# 246                              Se agrego el contador       traductor
# 247              Se configurará para crear un contador       traductor
# 248  Se perfeccionó el extremo comunista\n\nahora d...       traductor
# 249                                   favicon agregado       traductor
# 250                                               test       traductor
# 251        Agregado wallpaper\n\nSe estilizó la página       traductor
# 252  Fixeada las tildes mayúsculas\n\nahora si se r...       traductor
# 253  Se arregló responsividad\n\nahora funciona par...       traductor
# 16                                         commit test             AID
# 17                                        fixed readme             AID
# 18                                        first commit             AID
# 19                                   siguiendo clase 2  apuntes-mat023
# 20                                         fixed merge  apuntes-mat023
# 21                              avanzada segunda clase  apuntes-mat023
# 22        finalizada primera clase, comenzando segunda  apuntes-mat023
# 23   Merge branch 'master' of https://github.com/et...  apuntes-mat023
# 24                                                test  apuntes-mat023
# 25                                     avanzado cap 00  apuntes-mat023
# 26                                avanzado capitulo 00  apuntes-mat023
# 27                                        First commit  apuntes-mat023
# 28                                     modified images            blog
# 29                                            new note            blog
# ..                                                 ...             ...
# 228  Merge branch 'master' of https://github.com/et...        topshows
# 229                                    added gitignore        topshows
# 230                                   Update README.md        topshows
# 231                                   Update README.md        topshows
# 232                     now show the plots and save it        topshows
# 233  Merge branch 'master' of https://github.com/et...        topshows
# 234          fixed normal distribution -> distribution        topshows
# 235                                   Update README.md        topshows
# 236                                       finally done        topshows
# 237  Merge branch 'master' of https://github.com/et...        topshows
# 238                                       first commit        topshows
# 239                                     Initial commit        topshows
# 240                              fixed folders problem       traductor
# 241                                 reorganizing files       traductor
# 242  Se agregó un diccionario\n\nde ahora en adelan...       traductor
# 243                                      final counter       traductor
# 244                                               test       traductor
# 245                             testeado y funcionando       traductor
# 246                              Se agrego el contador       traductor
# 247              Se configurará para crear un contador       traductor
# 248  Se perfeccionó el extremo comunista\n\nahora d...       traductor
# 249                                   favicon agregado       traductor
# 250                                               test       traductor
# 251        Agregado wallpaper\n\nSe estilizó la página       traductor
# 252  Fixeada las tildes mayúsculas\n\nahora si se r...       traductor
# 253  Se arregló responsividad\n\nahora funciona par...       traductor
# 254  Arreglado reemplazo drástico\n\nya está totalm...       traductor
# 255                                       first commit       traductor
# 256                                       first commit         vimwiki
# 257                                       first commit  word-generator
#
#                    time
# 0   2017-12-09 01:38:39
# 1   2017-12-09 00:04:30
# 2   2017-12-09 00:04:06
# 3   2017-12-08 22:07:47
# 4   2017-12-08 19:35:27
# 5   2017-12-08 17:21:33
# 6   2017-12-08 01:29:07
# 7   2017-11-10 13:02:31
# 8   2017-11-10 12:43:58
# 9   2017-11-09 23:22:13
# 10  2017-10-31 19:45:03
# 11  2017-10-31 19:44:36
# 12  2017-09-29 19:15:31
# 13  2017-09-29 03:47:09
# 14  2017-09-26 03:06:44
# 15  2017-09-23 02:18:30
# 16  2017-09-22 18:57:48
# 17  2017-09-16 00:24:42
# 18  2017-09-16 00:23:08
# 19  2017-09-22 18:16:06
# 20  2017-09-16 21:37:23
# 21  2017-09-16 21:36:13
# 22  2017-09-16 19:40:42
# 23  2017-09-16 16:59:57
# 24  2017-09-16 16:59:24
# 25  2017-09-16 04:20:20
# 26  2017-09-16 04:16:12
# 27  2017-09-16 01:40:33
# 28  2017-11-04 18:52:05
# 29  2017-11-04 06:51:39
# ..                  ...
# 228 2017-04-20 23:28:13
# 229 2017-04-20 23:27:08
# 230 2017-04-19 03:17:47
# 231 2017-04-19 03:15:38
# 232 2017-04-19 03:05:44
# 233 2017-04-19 02:59:30
# 234 2017-04-19 02:59:18
# 235 2017-04-19 01:11:55
# 236 2017-04-19 00:39:15
# 237 2017-04-18 17:51:50
# 238 2017-04-18 17:43:30
# 239 2017-04-18 17:40:55
# 240 2017-05-29 16:22:19
# 241 2017-05-29 16:16:20
# 242 2016-09-02 02:11:52
# 243 2016-09-02 01:41:24
# 244 2016-09-02 01:31:20
# 245 2016-09-02 01:27:39
# 246 2016-09-02 01:21:35
# 247 2016-09-02 01:16:54
# 248 2016-09-01 17:25:03
# 249 2016-09-01 17:14:26
# 250 2016-09-01 15:36:43
# 251 2016-09-01 14:33:29
# 252 2016-09-01 13:50:28
# 253 2016-09-01 04:43:41
# 254 2016-09-01 04:30:01
# 255 2016-09-01 03:30:34
# 256 2017-10-19 03:31:01
# 257 2017-07-08 01:16:56
#
# [258 rows x 3 columns]

# %%
from datetime import date

fig, ax = plt.subplots(figsize=(8,7))
# se agrupa por mes
grouped = df.groupby(df['time'].apply(lambda x: date(year=x.year, month=x.month, day=1))).count()


grouped.plot(y='repository', ax=ax, label='Commits', color='steelblue')
ax.scatter(x=grouped.index, y=grouped['repository'], label='Commits', color='steelblue')

set_title(fig, ax, "Monthly commits", "Since account creation", [0, 0.1, 1, 0.92])
ax.text(0, -0.15, "Shaded zones are University semesters", fontsize=17, va='top', transform=ax.transAxes, fontweight='light')


import matplotlib.transforms as mtransforms

# truco para pintar por eje X
trans = mtransforms.blended_transform_factory(ax.transData, ax.transAxes)

# 2016-2
ax.fill_between(grouped.index, 0, 40, where=((grouped.index > date(2016,7,19)) & (grouped.index < date(2016,11,20))), 
                facecolor='steelblue', alpha=0.1, transform=trans)
# 2017-1
ax.fill_between(grouped.index, 0, 40, where=((grouped.index >= date(2017,3,1)) & (grouped.index < date(2017,7,19))), 
                facecolor='steelblue', alpha=0.1, transform=trans)

# 2017-2
ax.fill_between(grouped.index, 0, 40, where=((grouped.index >= date(2017,8,1)) & (grouped.index < date(2017,12,20))), 
                facecolor='steelblue', alpha=0.1, transform=trans)


plt.savefig("img/monthly_commit.png", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(8,7))

grouped = df.groupby(df['time'].apply(lambda x: x.hour)).count()
grouped = (grouped - grouped.min())/(grouped.max() - grouped.min())
grouped.plot(y="message", ax=ax, legend=False)
set_title(fig, ax, "Favourite hour to work", "Commits during the day", [0.02, 0, 1, 0.9])
ax.set_xticks(range(0, 25, 2));
ax.set_xlabel("Hour")
ax.set_ylabel("Normalized amount of commits")
ax.set_xlim(0, 23)
#ax.text(1, -0.1, "@EtraStyle", va='bottom', ha='right', alpha=0.5, transform=ax.transAxes)
fig.savefig("img/commit_hours.png", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(8,7))
# se agrupa por mes
temp = df.copy()
temp['weekday'] = temp['time'].apply(lambda x: x.strftime("%u"))

grouped = temp.groupby('weekday').count()
grouped = grouped.reset_index()
grouped['weekday'] = pd.to_numeric(grouped['weekday'])

grouped['time'] = (grouped['time'] - grouped['time'].min())/(grouped['time'].max() - grouped['time'].min())

grouped.plot(x='weekday', y='time', ax=ax)
ax.set_xticklabels(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
ax.set_xticks(range(1, 8, 1))
ax.set_xlabel("")
ax.set_ylabel("Normalized ammount of commits")
set_title(fig, ax, "Favourite weekday to work", "According commits during the week")

fig.savefig("img/commit_week.png", dpi=300)

# %%
df.groupby('repository').count().sort_values(by='message', ascending=False).head()
# Out:
#                message  time
# repository
# SansanoBot          30    30
# ramos               23    23
# ElepemonGO          22    22
# StemReveal.js       20    20
# AID                 19    19
